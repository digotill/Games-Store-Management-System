# %% [markdown]
# <a href="https://colab.research.google.com/github/digotill/Games-Store-Management-System/blob/main/Menu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import ipywidgets as widgets

import database  as db
import booking as bk
import subscriptionManager as sm
import feedbackManager as fm
import gameRent as grt
import gameReturn as grtn
import pruning as pn

# %%
# Check Feedback Manager Works.
feedback_list = fm.load_feedback()
print(feedback_list)  # Should print the list of feedback records.
fm.add_feedback("dft01", 4, "Not bad", "Game_Feedback.txt")

# Check Subscription Manager Works.
subscriptions = sm.load_subscriptions()
print(sm.check_subscription("lbro", subscriptions))
# Should return True or False based on the current date.
print(sm.get_rental_limit("Basic"))  # Should return 2.
print(sm.get_rental_limit("Premium"))  # Should return 7.
# Out:
# [{'GameID': 'dft01', 'Rating': 4, 'Comments': 'Not bad'}, {'GameID': 'dft01', 'Rating': 4, 'Comments': 'Not bad'}, {'GameID': 'dft01', 'Rating': 4, 'Comments': 'Not bad'}, {'GameID': 'dft01', 'Rating': 4, 'Comments': 'Not bad'}, {'GameID': 'dft01', 'Rating': 4, 'Comments': 'Not bad'}, {'GameID': 'dft01', 'Rating': 4, 'Comments': 'Not bad'}, {'GameID': 'dft01', 'Rating': 4, 'Comments': 'Not bad'}]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 7
#       4 fm.add_feedback("dft01", 4, "Not bad", "Game_Feedback.txt")
#       6 # Check Subscription Manager Works.
# ----> 7 subscriptions = sm.load_subscriptions()
#       8 print(sm.check_subscription("lbro", subscriptions))
#       9 # Should return True or False based on the current date.
#
# File ~\OneDrive\Documents\Games-Store-Management-System\PY Files\subscriptionManager.py:41, in load_subscriptions(file_name)
#      34 def load_subscriptions(file_name='Subscription_Info.txt'):
#      35           """
#      36           Load subscription information from a text file into a dictionary.
#      37
#      38           Parameters:
#      39               file_name (str): The name of the text file containing subscription information.
#      40
# ---> 41           Returns:
#      42               dict: A dictionary containing customer IDs as keys and their subscription details as values.
#      43           """
#      44           subscriptions = {}
#      45           with open(os.path.abspath(os.path.join(cur_path, os.pardir)) + '\\' + 'TXT Files' + '\\' + file_name, 'r') as file:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Subscription_Info.txt'

# %%
button = widgets.Button(description="Click Me!")
output = widgets.Output()

def on_button_clicked():
    pass

button.on_click(on_button_clicked)
widgets.HBox([button, output])
# Out:
# HBox(children=(Button(description='Click Me!', style=ButtonStyle()), Output()))
