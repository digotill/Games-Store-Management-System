# %% [markdown]
# <a href="https://colab.research.google.com/github/digotill/Games-Store-Management-System/blob/main/Menu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import ipywidgets as widgets

import database  as db
import booking as bk
import subscriptionManager as sm
import feedbackManager as fm
import gameRent as grt
import gameReturn as grtn
import pruning as pn
import gameSearch as gs

# %%
# Check Feedback Manager Works.
feedback_list = fm.load_feedback()
print(feedback_list)  # Should print the list of feedback records.
fm.add_feedback("dft01", 4, "Not bad", "Game_Feedback.txt")

# Check Subscription Manager Works.
subscriptions = sm.load_subscriptions()
print(sm.check_subscription("lbro", subscriptions))

print(sm.get_rental_limit("Basic"))  # Should return 2.
print(sm.get_rental_limit("Premium"))  # Should return 7.
# Out:
# [{'GameID': 'Art01', 'Rating': 4, 'Comments': 'Hilarious!'}, {'GameID': 'bac02', 'Rating': 2, 'Comments': 'Not exciting'}, {'GameID': 'chs03', 'Rating': 5, 'Comments': 'My favourite game of all time'}, {'GameID': 'dft01', 'Rating': 4, 'Comments': 'Not bad'}, {'GameID': 'dft01', 'Rating': 4, 'Comments': 'Not bad'}, {'GameID': 'dft01', 'Rating': 4, 'Comments': 'Not bad'}]
# C:\Users\digot\PycharmProjects\Games-Store-Management-System\TXT Files\Subscription_Info.txt
# True
# 2
# 7

# %%
button = widgets.Button(description="Click Me!")
output = widgets.Output()

def on_button_clicked():
    pass

button.on_click(on_button_clicked)
widgets.HBox([button, output])


digitalGameSearch = gs.loadGameSearch(["digital"])
print(digitalGameSearch)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 11
#       7 button.on_click(on_button_clicked)
#       8 widgets.HBox([button, output])
# ---> 11 digitalGameSearch = gs.loadGameSearch(["digital"])
#      12 print(digitalGameSearch)
#
# File ~\PycharmProjects\Games-Store-Management-System\PY Files\gameSearch.py:5, in loadGameSearch(gameType)
#       2 Games = {}
#       4 if "digital" in gameType:
# ----> 5           with open(os.path.join(os.path.abspath(os.path.join(cur_path, os.pardir)), 'TXT Files', 'digitalGameInfo.txt'), 'r', encoding='utf-8') as file:
#       6                     reader = csv.reader(file)
#       7                     next(reader)
#
# NameError: name 'os' is not defined
