# %%
from GameSearching import *
from Renting import *
from Returning import *
from SubscriberSearching import *
from Booking import *

tab_widget = widgets.Tab()
tab_widget.children = [Search_Tab, Subscribers_Tab, Renting_Tab, Returning_Tab, Booking_Tab]
tab_widget.titles = ["Game Search", "Subscriber Search", "Renting", "Returning", "Booking"]
display(tab_widget)

# %%
from Generation import *

display(generation_widget)
