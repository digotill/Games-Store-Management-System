# %% [markdown]
# <a href="https://colab.research.google.com/github/digotill/Games-Store-Management-System/blob/main/Menu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import ipywidgets as widgets

# %%
from google.colab import files
uploaded = files.upload()

# %%
import subscriptionManager as smSL
import feedbackManager as fmSL

# Check Feedback Manager Works.
feedback_list = fmSL.load_feedback()
print(feedback_list)  # Should print the list of feedback records.
fmSL.add_feedback("dft01", 4, "Not bad", "Game_Feedback.txt")

# Check Subscription Manager Works.
subscriptions = smSL.load_subscriptions()
print(smSL.check_subscription("lbro", subscriptions))
# Should return True or False based on the current date.
print(smSL.get_rental_limit("Basic"))  # Should return 2.
print(smSL.get_rental_limit("Premium"))  # Should return 7.
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 import subscriptionManager as smSL
#       2 import feedbackManager as fmSL
#       4 # Check Feedback Manager Works.
#
# ImportError: bad magic number in 'subscriptionManager': b'\xcb\r\r\n'

# %%
button = widgets.Button(description="Click Me!")
output = widgets.Output()

def on_button_clicked():
    pass

button.on_click(on_button_clicked)
widgets.HBox([button, output])
# Out:
# HBox(children=(Button(description='Click Me!', style=ButtonStyle()), Output()))
